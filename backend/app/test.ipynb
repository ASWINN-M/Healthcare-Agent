# %%
# !pip install mysql_connector
# Out:
# Hello

# %%
import mysql.connector
import os
def get_connection(database):
    return mysql.connector.connect(
        host="127.0.0.1",
        user=os.getenv("root"),
        password=os.getenv("Msaa@1234"),
        database=database,
        port=int(os.getenv("DB_PORT", 3306))
    )


temp = get_connection("DoctorDB")
if temp:
    print("Connection successful!")
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[5], line 13
#       3 def get_connection(database):
#       4     return mysql.connector.connect(
#       5         host="127.0.0.1",
#       6         user=os.getenv("root"),
#    (...)      9         port=int(os.getenv("DB_PORT", 3306))
#      10     )
# ---> 13 temp = get_connection("DoctorDB")
#      14 if temp:
#      15     print("Connection successful!")
#
# Cell In[5], line 4, in get_connection(database)
#       3 def get_connection(database):
# ----> 4     return mysql.connector.connect(
#       5         host="127.0.0.1",
#       6         user=os.getenv("root"),
#       7         password=os.getenv("Msaa@1234"),
#       8         database=database,
#       9         port=int(os.getenv("DB_PORT", 3306))
#      10     )
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\__init__.py:179, in connect(*args, **kwargs)
#     177     return CMySQLConnection(*args, **kwargs)
#     178 else:
# --> 179     return MySQLConnection(*args, **kwargs)
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\connection.py:95, in MySQLConnection.__init__(self, *args, **kwargs)
#      92 self._pool_config_version = None
#      94 if len(kwargs) > 0:
# ---> 95     self.connect(**kwargs)
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\abstracts.py:716, in MySQLConnectionAbstract.connect(self, **kwargs)
#     713     self.config(**kwargs)
#     715 self.disconnect()
# --> 716 self._open_connection()
#     717 self._post_connection()
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\connection.py:208, in MySQLConnection._open_connection(self)
#     206 self._socket.open_connection()
#     207 self._do_handshake()
# --> 208 self._do_auth(self._user, self._password,
#     209               self._database, self._client_flags, self._charset_id,
#     210               self._ssl)
#     211 self.set_converter_class(self._converter_class)
#     212 if self._client_flags & ClientFlag.COMPRESS:
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\connection.py:144, in MySQLConnection._do_auth(self, username, password, database, client_flags, charset, ssl_options)
#     137 packet = self._protocol.make_auth(
#     138     handshake=self._handshake,
#     139     username=username, password=password, database=database,
#     140     charset=charset, client_flags=client_flags,
#     141     ssl_enabled=self._ssl_active,
#     142     auth_plugin=self._auth_plugin)
#     143 self._socket.send(packet)
# --> 144 self._auth_switch_request(username, password)
#     146 if not (client_flags & ClientFlag.CONNECT_WITH_DB) and database:
#     147     self.cmd_init_db(database)
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\connection.py:169, in MySQLConnection._auth_switch_request(self, username, password)
#     165 (new_auth_plugin,
#     166  auth_data) = self._protocol.parse_auth_switch_request(packet)
#     167 auth = get_auth_plugin(new_auth_plugin)(
#     168     auth_data, password=password, ssl_enabled=self._ssl_active)
# --> 169 response = auth.auth_response()
#     170 self._socket.send(response)
#     171 packet = self._socket.recv()
#
# File c:\sl-ai\.venv\Lib\site-packages\mysql\connector\authentication.py:78, in BaseAuthPlugin.auth_response(self)
#      70 """Returns the prepared password to send to MySQL
#      71
#      72 Raises InterfaceError on errors. For example, when SSL is required
#    (...)     75 Returns str
#      76 """
#      77 if self.requires_ssl and not self._ssl_enabled:
# ---> 78     raise errors.InterfaceError("{name} requires SSL".format(
#      79         name=self.plugin_name))
#      80 return self.prepare_password()
#
# InterfaceError: sha256_password requires SSL

# %%
# !pip install mysql_connector
# Out:
# Requirement already satisfied: mysql_connector in c:\users\aswin\anaconda3\lib\site-packages (2.2.9)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import mysql.connector
from dotenv import load_dotenv

load_dotenv()

def get_connection(database):
    return mysql.connector.connect(
        host=os.getenv("DB_HOST"),
        user=os.getenv("root"),
        password=os.getenv("Msaa@1234"),
        database=database,
        port=int(os.getenv("DB_PORT", 3306))
    )




print("DB_USER:", os.getenv("DB_USER"))
print("DB_PASSWORD:", os.getenv("DB_PASSWORD"))
print("DB_PORT:", os.getenv("DB_PORT"))
# Out:
# DB_USER: None
# DB_PASSWORD: None
# DB_PORT: None

# %%
# !mysql -u root -p
# Out:
# 'mysql' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os
import mysql.connector
from dotenv import load_dotenv

load_dotenv()

def get_connection(database):
    return mysql.connector.connect(
        host=os.getenv("DB_HOST"),
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        database=database,
        port=int(os.getenv("DB_PORT", 3306))
    )



print("DB_HOST:", os.getenv("DB_HOST"))
print("DB_USER:", os.getenv("DB_USER"))
print("DB_PASSWORD:", os.getenv("DB_PASSWORD"))
print("DB_PORT:", os.getenv("DB_PORT"))
# Out:
# DB_HOST: 127.0.0.1
# DB_USER: root
# DB_PASSWORD: Msaa@1234
# DB_PORT: 3306
